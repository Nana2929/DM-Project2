# %%
# %load_ext autoreload
# %autoreload 2

from classifier import *

# %%
dt_classify(0)
# Out:
# =========== Decision Tree ============
# Reading anime_dataset_10000-0.csv...
# class counts:bland          9226
# refreshing      446
# masterpiece     328
# Name: class, dtype: int64
# Macro F1: 0.935
# Score: 0.985
# avg_rating	0.095 +/- 0.006
# in_seiyuu_rank	0.079 +/- 0.005
# author  	0.039 +/- 0.002
# style   	0.037 +/- 0.004
# theme_singer	0.033 +/- 0.004
# studio_staff_num	0.014 +/- 0.002
# #seasons	0.009 +/- 0.002
# avg_ep_length	0.007 +/- 0.002

# %%
dt_classify(0.05)
# Out:
# =========== Decision Tree ============
# Reading anime_dataset_10000-0.05.csv...
# class counts:bland          8789
# refreshing      652
# masterpiece     559
# Name: class, dtype: int64
# Macro F1: 0.767
# Score: 0.936
# avg_rating	0.080 +/- 0.005
# in_seiyuu_rank	0.068 +/- 0.005
# style   	0.036 +/- 0.004
# theme_singer	0.034 +/- 0.003
# author  	0.031 +/- 0.002
# studio_staff_num	0.015 +/- 0.002
# avg_ep_length	0.007 +/- 0.001
# #seasons	0.007 +/- 0.001

# %%
print('=========== Naive Bayes ============')
bayes_classify(0)
# Out:
# =========== Naive Bayes ============
# Reading anime_dataset_10000-0.csv...
# class counts:bland          9226
# refreshing      446
# masterpiece     328
# Name: class, dtype: int64
# Score: 0.734
# Macro F1: 0.521
# in_seiyuu_rank	0.075 +/- 0.006
# avg_rating	0.044 +/- 0.005
# style   	0.012 +/- 0.002
# theme_singer	0.012 +/- 0.002
# studio_staff_num	0.006 +/- 0.002

# %%
print('=========== Naive Bayes ============')
bayes_classify(0.05)
# Out:
# =========== Naive Bayes ============
# Reading anime_dataset_10000-0.05.csv...
# class counts:bland          8789
# refreshing      652
# masterpiece     559
# Name: class, dtype: int64
# Score: 0.887
# Macro F1: 0.387
# avg_rating	0.010 +/- 0.002
# in_seiyuu_rank	0.008 +/- 0.001
# style   	0.005 +/- 0.001
# studio_staff_num	0.003 +/- 0.001
# theme_singer	0.003 +/- 0.001
