# %%
from clf_decision_tree import *

# %%
dt_classify(0)
# Out:
# =========== Decision Tree ============
# Reading anime_dataset_10000-0.csv...
# class counts:bland          9226
# refreshing      446
# masterpiece     328
# Name: class, dtype: int64
# Score: 0.978
# avg_rating	0.089 +/- 0.005
# in_seiyuu_rank	0.072 +/- 0.005
# style   	0.039 +/- 0.003
# theme_singer	0.035 +/- 0.002
# author  	0.028 +/- 0.003
# studio_staff_num	0.019 +/- 0.003
# avg_ep_length	0.006 +/- 0.001

# %%
dt_classify(0.05)
# Out:
# =========== Decision Tree ============
# Reading anime_dataset_10000-0.05.csv...
# class counts:bland          8789
# refreshing      652
# masterpiece     559
# Name: class, dtype: int64
# Score: 0.919
# avg_rating	0.069 +/- 0.005
# in_seiyuu_rank	0.060 +/- 0.004
# author  	0.044 +/- 0.004
# theme_singer	0.017 +/- 0.003
# studio_staff_num	0.014 +/- 0.002
# #seasons	0.005 +/- 0.001

# %%
bayes_classify(0)
# Out:
# Reading anime_dataset_10000-0.csv...
# class counts:bland          9226
# refreshing      446
# masterpiece     328
# Name: class, dtype: int64
# Score: 0.739
# in_seiyuu_rank	0.082 +/- 0.008
# avg_rating	0.038 +/- 0.008
# style   	0.013 +/- 0.003
# theme_singer	0.011 +/- 0.003

# %%
bayes_classify(0)
# Out:
# Reading anime_dataset_10000-0.csv...
# class counts:bland          9226
# refreshing      446
# masterpiece     328
# Name: class, dtype: int64
# Score: 0.751
# in_seiyuu_rank	0.081 +/- 0.006
# avg_rating	0.046 +/- 0.007
# style   	0.014 +/- 0.003
# theme_singer	0.014 +/- 0.003
# author  	0.010 +/- 0.004
# studio_staff_num	0.006 +/- 0.002
